# %% [markdown]
# <a href="https://colab.research.google.com/github/jorgeordonez2209/daa_1511_2021/blob/main/Tarea6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class NodoArbol:
  def __init__(self, value, left = None, rigth= None):
    self.data = value
    self.left = left
    self.rigth = rigth

class ArbolBB:
  def __init__(self):
    self.__root = None
  
  def insert(self, value):
    if self.__root == None:
      self.__root = NodoArbol(value)
    else:
      self.__insert_nodo__(self.__root, value) 

  def __insert_nodo__(self, nodo, value):
    if nodo.data == value:
      print(f"Ya existe {value}")
      pass
    elif value < nodo.data:
      if nodo.left == None:
        nodo.left = NodoArbol(value)
      else: 
        self.__insert_nodo__(nodo.left, value)
    else:
      if nodo.rigth == None:
        nodo.rigth = NodoArbol(value)
      else: 
        self.__insert_nodo__(nodo.rigth, value)

  # preorden posorden
  def transversal(self, formato="inorden"):
    if formato =="inorden":
      print("InOrden")
      self.recorrido_in(self.__root)
    elif formato == "preorden":
      print("Preorden")
      self.recorrido_pre(self.__root)
    else: #post
      print("Pos orden")
      self.recorrido_pos(self.__root)

  def recorrido_in(self, nodo):
    if nodo != None:
      self.recorrido_in(nodo.left)
      print(nodo.data, end = "  ") #end = " " para eliminar salto de linea
      self.recorrido_in(nodo.rigth)

  def recorrido_pre(self, nodo):
    if nodo != None:
      print(nodo.data, end = "  ") #end = " " para eliminar salto de linea
      self.recorrido_pre(nodo.left)
      self.recorrido_pre(nodo.rigth)

  def recorrido_pos(self, nodo):
    if nodo != None:
      self.recorrido_pos(nodo.left)
      self.recorrido_pos(nodo.rigth)
      print(nodo.data, end = "  ") #end = " " para eliminar salto de linea

  def buscar(self, value):
    if self.__root == None:
      print("Árbol vacío")
      return None
    else:
      return self.busca_nodo(self.__root, value)

  def busca_nodo(self, nodo, value):
    if nodo == None:
      print("No existe")
      return None
    elif nodo.data == value:
      print("Encontrado", nodo.data)
      return nodo
    elif value < nodo.data:
      print("Buscar del lado izq")
      return self.busca_nodo(nodo.left, value)
    else: 
      print("Buscar lado derecho")
      return self.busca_nodo(nodo.rigth, value)


# Eliminar nodo  
  def eliminar(self, value):
    if self.__root == None:
      print("Nada que eliminar")
    else:
      self.eliminar_nodo(None, None, self.__root, value)

  def eliminar_nodo(self, padre_hi, padre_hd, actual, value):
    if actual == None:
      print("No existe")
      return None
    elif actual.data == value:
      print("Encontrado: ", actual.data)
      
      if actual.left == None and actual.rigth == None:
        if padre_hi != None:
          padre_hi.left = None
        else:
          padre_hd.rigth = None
      
      if (actual.left != None and actual.rigth == None) or (actual.left == None and actual.rigth != None):
        if actual.left != None:
          actual.data = actual.left.data
          actual.left = None
        else:
          actual.data = actual.right.data
          actual.rigth = None
      

    elif value < actual.data:
      self.eliminar_nodo(actual, None, actual.left, value)
    else:
      self.eliminar_nodo(None, actual, actual.rigth, value)

# %%
abb = ArbolBB()

abb.insert(50)
abb.insert(25)
abb.insert(30)
abb.insert(10)
abb.insert(60)
abb.insert(5)
abb.insert(15)
abb.insert(28)
abb.insert(31)

abb.transversal("inorden")
print("")
abb.transversal("preorden")
print("")
abb.transversal("")
print("")
res = abb.buscar(15)

abb.eliminar(11)
abb.eliminar(60)

abb.transversal("inorden")
print("")
abb.transversal("preorden")
print("")
abb.transversal("")
print("")
res = abb.buscar(15)
# Out:
# InOrden
# 5  10  15  25  28  30  31  50  60
# Preorden
# 50  25  10  5  15  30  28  31  60
# Pos orden
# 5  15  10  28  31  30  25  60  50
# Buscar del lado izq
# Buscar del lado izq
# Buscar lado derecho
# Encontrado 15
# No existe
# Encontrado:  60
# InOrden
# 5  10  15  25  28  30  31  50
# Preorden
# 50  25  10  5  15  30  28  31
# Pos orden
# 5  15  10  28  31  30  25  50
# Buscar del lado izq
# Buscar del lado izq
# Buscar lado derecho
# Encontrado 15
